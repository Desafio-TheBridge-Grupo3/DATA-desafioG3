# %%
import re
from pdfminer.high_level import extract_text

# %%
text = extract_text("pdf_moron.pdf")

# %%
print(text)
# Out:
# 9
# 8
# 3
# 8
# 5
# 7
# 5
# 9
# -
# A
# F
# C
# -
#
# I
#
# i
#
# ª
# 1
# n
# ó
# c
# p
# i
# r
# c
# s
# n
#
# i
#
# ,
# 1
# 8
# 9
# 3
# 6
# -
# I
# B
# a
# o
# h
#
# j
#
# ,
#
# 9
# 1
# o
#
# i
# l
#
# o
# f
#
# ,
#
# 8
# 4
# 4
# 5
# o
# m
# o
# t
#
# ,
#
# i
#
# a
# a
# k
# z
# B
# e
# d
#
# i
#
# l
# i
# t
# n
# a
# c
# r
# e
# M
# o
# r
# t
# s
# g
# e
# R
#
# i
#
# l
# e
# n
# e
# a
# t
# i
# r
# c
# s
# n
#
# i
#
# ;
#
# o
# a
# b
#
# l
# i
#
# B
# 9
# 0
# 0
# 8
# 4
#
# ,
#
# 5
#
# i
#
# d
# a
# k
# s
# u
# E
# a
# z
# a
# l
# P
#
# i
#
# :
# l
# a
# c
# o
# s
# o
#
# i
#
# i
# l
# i
# c
# m
# o
# d
#
# ;
#
# d
# i
# r
# d
# a
# M
# 3
# 3
# 0
# 8
# 2
#
# ,
# 1
# o
# d
# n
# o
# d
# e
# R
# s
# á
# m
# o
# T
# /
# C
#
# :
# l
# a
# c
# s
# i
# f
# o
#
# i
#
# i
# l
# i
# c
# m
# o
# d
# -
#
# .
#
# .
#
# U
# A
# S
#
# .
#
# ,
#
# I
#
# S
# E
# T
# N
# E
# L
# C
# A
# L
# O
# R
# D
# R
# E
# B
#
# I
#
# r
# o
# p
# o
# d
# i
# t
# i
#
# m
# e
# o
# t
# n
# e
# m
# u
# c
# o
# D
#
# FACTURA DE
# ELECTRICIDAD
#
# IBERDROLA CLIENTES, S.A.U.
# CIF A-95758389
#
# CONTRATO
#
# Titular
#
# ADRIAN MORON BLANCO
#
# Dirección de suministro:
#
# Plza ANDATZA, 4, 2º C  20160
# LASARTE-ORIA (GIPUZKOA)
#
# Potencia:
#
# Potencia punta: 3,3 kW
# Potencia valle: 3,3 kW
#
# Nº DE CONTRATO: 867694233
#
# RESUMEN DE FACTURA
#
# PERIODO DE FACTURACIÓN:
# 08/10/2023 - 08/11/2023
#
# Nº FACTURA:
# 21231113010286565
#
# DIAS FACTURADOS:
# 31
#
# FECHA DE EMISIÓN:
# 13 de noviembre de 2023
#
# ENERGÍA............................................................................ 62,82 €
#
# DESCUENTOS ENERGÍA .............................................. -9,38 €
#
# CARGOS NORMATIVOS ................................................... 1,19 €
#
# SERVICIOS Y OTROS CONCEPTOS.......................... 0,83 €
#
# IVA........................................................................................... 2,77 €
#
# TOTAL
#
# 58,23 €
#
# FECHA PREVISTA DE COBRO: 21/11/2023
#
# Remite: IBERDROLA CLIENTES, S.A.U. Apartado de Correos 61175 28080 Madrid
#
# DY 910 M S 0867694233 0 1 08
#
# SV01   004959   019817   20231113
#
# (cid:106)(cid:103)(cid:9)(cid:68)(cid:70)(cid:43)(cid:34)(cid:1)(cid:34)(cid:92)(cid:3)(cid:2)(cid:61)(cid:21)(cid:91)(cid:21)(cid:1)(cid:11)(cid:12)(cid:32)(cid:14)(cid:6)(cid:107)
# 08676942330033910201602090200010113113
#
# ADRIAN MORON BLANCO
#
# Plza ANDATZA, 4, 2º C
#
# 20160 LASARTE-ORIA (GIPUZKOA)
#
# Puede  encontrar  el  desglose  detallado  de  los  conceptos
# facturados  en  el  reverso  de  esta  factura.  Además,  en
# iberdrola.info/factura-luz le  explicamos con  detalle la  factura,
# para que entenderla sea más fácil que nunca.
#
# ¿LE PODEMOS AYUDAR?
#
# ps
#
# www.iberdrola.es    clientes@tuiberdrola.es
#
# APP Iberdrola Clientes
#
# Oficina de Atención Iberdrola:
# CALLE MAYOR 44 20160 LASARTE-ORIA
# CALLE ELKANO KALEA 13 20120 HERNANI
#
# Atención al Cliente
# 900 225 235
# 94 646 01 25
#
# Reparaciones
# eléctricas del hogar
#
# 900 22 45 22
# 94 646 29 31
#
# Notificación
# de averías en la zona
#
# 900171171
#
# i-DE, Redes Eléctricas
# Inteligentes, S.A.U.
#
# 1/4
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         INFORMACIÓN SOBRE CONSUMO
#
#      EVOLUCIÓN DE CONSUMO (kWh)
#
# 400
#
# 300
#
# 200
#
# 100
#
# kWh
#
# Oc.
# 23
#
# Nv.
# 23
#
# DETALLE DE FACTURA
# DETALLE DE FACTURA
#
# ENERGÍA
#
# Potencia facturada
#
# 242 kWh
#
# 1,87 €
#
# 2,17 €
#
# Consumo total de
# esta factura.
#
# Consumo medio diario
# en esta factura.
#
# Consumo medio diario
# en los últimos 1 meses.
#
# Puede consultar el detalle de su consumo hora a hora en Mi Área Cliente en www.iberdrola.es
# y en la APP de Iberdrola Clientes. También puede acceder a los datos de medida de su
# contador inteligente a través de la web de su empresa distribuidora www.i-de.es/clientes.
#
# Punta 3,3 kW x 31 días x 0,099528 €/kW día
#
# Valle 3,3 kW x 31 días x 0,016405 €/kW día
#
# Total importe potencia hasta 08/11/2023
#
# 11,86 €
#
# Energía consumida
#
# Descuento sobre consumo 15%
#
# Descuento sobre T. Potencia
#
# CARGOS NORMATIVOS
#
# Financiación bono social fijo
#
# Impuesto sobre electricidad (*)
#
# TOTAL ENERGÍA
#
# SERVICIOS Y OTROS CONCEPTOS
#
# Alquiler equipos medida
#
# Asistente Smart Iberdrola
#
# Dto Asistente Smart
#
# TOTAL SERVICIOS Y OTROS CONCEPTOS
#
# IMPORTE TOTAL
#
# IVA Reducido (*)
#
# TOTAL IMPORTE FACTURA
#
# 242 kWh  x  0,209469 €/kWh
#
# 15% s/50,69 €
#
# 15% s/11,86 €
#
# 31 días  x  0,038455 €/día
#
# 0,5% s/54,36 €
#
# 31 días  x  0,02663 €/día
#
# 1,01 meses  x  0,99 €/mes
#
# 100% s/1 €
#
# 5% s/55,46 €
#
# INFORMACION ADICIONAL
#
# NIF titular del contrato:
#
# Nº contador:
#
# 53901164C
#
# 0000082040
#
# Peaje de acceso a la red (ATR):
#
# 2.0TD
#
# Precios de peajes de acceso:
#
# B.O.E. del 22/12/2022
#
# El 13,3% está
# destinado a
# impuestos y cargos
#
# Fecha final del contrato:
#
# Empresa distribuidora:
#
# 06/10/2024
#
# i-DE, Redes Eléctricas Inteligentes, S.A.U.
#
# 17,2%
#
# Número de contrato de acceso:
#
# 0027783790
#
# Identificación punto de suministro (CUPS):
#
# ES 0021 0000 0351 8693 SN
#
# Forma de pago:
#
# IBAN:
#
# BIC:
#
# Código de mandato:
#
# **** (Ocultos para su seguridad)
#
# DOMICILIACION BANCARIA
#
# ES65 0030 1137 6003 9086 ****
#
# BSCHESMMXXX
#
# 275464214000
#
# 66,1%
#
# 5,2%
#
# 1,4%
#
# 8,1%
#
# 2,0%
#
# Energía
# Peajes de Transporte y Distribución
#
# Impuestos
#
# Alquiler contador
#
# Bono Social
#
# Cargos
#
# Renovables, cogeneración y residuos
#
# Anualidades del déficit
#
# Sobrecoste generación no peninsular
#
# Otros
#
# 0,0%
#
# 6,5%
#
# 1,5%
#
# 0,1%
#
# (*) En virtud del Real Decreto-ley 17/2021, de 14 de septiembre, el impuesto especial sobre la electricidad aplicable a su factura se encuentra reducido
# del 5,11269632% al 0,5%.
#
# Las lecturas desagregadas según la tarifa de acceso, tomadas el 08/11/2023 son: punta: 1.319 kWh; llano: 1.021 kWh; valle 324 kWh, siendo estas lecturas
# reales. Sus consumos desagregados han sido punta: 68 kWh; llano: 68 kWh; valle 106 kWh.
#
# Las potencias máximas demandadas en el último año han sido 2,64 kW en P1 (punta) y 2,7 kW en P2 (valle).
#
# Para el periodo de esta factura el consumo medio de electricidad de los suministros en su mismo código postal ha sido de 159,21 kWh.
#
# El importe de los peajes de acceso a redes en esta factura, sin impuestos, es de 15,56 €, desglosado en: Potencia: 7,49 € , Energía: 7,24 €, Alquiler de
# contador: 0,83 €. Impuestos aplicables:  Impuesto Eléctrico e IVA u otros impuestos indirectos. Estos importes están englobados en el importe total de
# la factura (no representan coste adicional).
#
# Para reclamaciones relacionadas con el contrato de suministro o la facturación puede dirigirse a cualquiera de los canales de atención indicados en esta
# factura, o en el Apartado de Correos 61090, 28080 de Madrid. Si su reclamación no ha sido resuelta o ha superado el plazo de 30 días, puede dirigirse a
# la Junta Arbitral de Consumo de su Comunidad Autónoma. Además puede acudir a los órganos competentes en materia de Consumo y/o Energía de
# dicha Comunidad Autónoma.
#
# Certificado PEFC. Este papel procede de bosques gestionados de forma sostenible y fuentes controladas. www.pefc.es
#
# 10,18 €
#
# 1,68 €
#
# 50,69 €
#
# -7,60 €
#
# -1,78 €
#
# 1,19 €
#
# 0,27 €
#
# 54,63 €
#
# 0,83 €
#
# 1,00 €
#
# -1,00 €
#
# 0,83 €
#
# 55,46 €
#
# 2,77 €
#
# 58,23 €
#
# 66,1%
# 17,2%
#
# 5,2%
#
# 1,4%
#
# 2,0%
#
# 8,1%
#
# (cid:209)
#
# (cid:118)
# (cid:108)
# (cid:118)
# (cid:117)
#
# 0
# 1
# 0
# 0
# 0
# (cid:269)(cid:292)(cid:212)(cid:252)(cid:292)(cid:292)(cid:253)(cid:274)(cid:337)(cid:293)(cid:284)(cid:304)(cid:222)(cid:214)(cid:248)(cid:312)(cid:283)(cid:298)(cid:235)(cid:302)(cid:257)(cid:299)(cid:286)(cid:317)(cid:221)(cid:262)(cid:337)(cid:312)(cid:305)(cid:266)(cid:332)(cid:218)(cid:257)(cid:222)(cid:252)(cid:225)(cid:322)(cid:282)(cid:258)(cid:306)(cid:334)(cid:271)(cid:248)(cid:244)(cid:334)(cid:272)(cid:309)(cid:263)(cid:311)(cid:234)(cid:235)(cid:273)(cid:302)(cid:276)(cid:289)(cid:330)(cid:300)(cid:218)(cid:289)(cid:297)(cid:228)(cid:277)(cid:278)(cid:285)(cid:241)(cid:300)(cid:306)(cid:286)(cid:302)(cid:272)(cid:244)(cid:313)(cid:324)(cid:309)(cid:296)(cid:314)(cid:211)(cid:267)(cid:260)(cid:302)(cid:273)(cid:250)(cid:300)(cid:282)(cid:225)(cid:238)(cid:239)(cid:334)(cid:214)
# (cid:334)(cid:214)(cid:326)(cid:326)(cid:326)(cid:214)(cid:334)(cid:210)(cid:262)(cid:218)(cid:230)(cid:314)(cid:318)(cid:318)(cid:314)(cid:290)(cid:230)(cid:250)(cid:278)(cid:234)(cid:286)(cid:214)(cid:234)(cid:254)(cid:306)(cid:286)(cid:326)(cid:246)(cid:294)(cid:274)(cid:322)(cid:274)(cid:322)(cid:258)(cid:250)(cid:334)(cid:242)(cid:314)(cid:242)(cid:254)(cid:218)(cid:214)(cid:234)(cid:278)(cid:222)(cid:266)(cid:326)(cid:234)(cid:290)(cid:266)(cid:326)(cid:302)(cid:250)(cid:330)(cid:278)(cid:294)(cid:334)(cid:330)(cid:286)(cid:222)(cid:302)(cid:282)(cid:330)(cid:318)(cid:254)(cid:306)(cid:330)(cid:250)(cid:226)(cid:290)(cid:238)(cid:222)(cid:310)(cid:238)(cid:218)(cid:254)(cid:282)(cid:210)(cid:218)(cid:302)(cid:278)(cid:318)(cid:274)(cid:326)(cid:274)(cid:238)(cid:210)(cid:286)(cid:226)
#
# 3/4
#
#
# Página   4 / 4
#
# Origen de electricidad 2022
#
# Si bien la energía eléctrica que llega a nuestros hogares es indistinguible de la que consumen nuestros vecinos u otros consumidores
# conectados al mismo sistema eléctrico, es posible conocer el origen de la producción de energía eléctrica equivalente a la que
# consume en el hogar.
# A estos efectos, se proporciona el desglose de la mezcla de tecnologías de producción nacional para así comparar los porcentajes del
# promedio nacional con los correspondientes a la energía vendida por su Compañía Comercializadora.
#
# Iberdrola Clientes
#
# Origen
#
# Iberdrola Clientes Mix de generación nacional
#
# Renovable
#
# Cogen. Alta
# Eﬁciencia
#
# CC Gas Natural
#
# Carbón
#
# Fuel/Gas
#
# Nuclear
#
# Otras no renovables
#
# 42,7%
#
# 3,1%
#
# 25,1%
#
# 2,8%
#
# 1,1%
#
# 20,2%
#
# 5,0%
#
# 42,3%
#
# 2,1%
#
# 25,7%
#
# 2,9%
#
# 1,1%
#
# 20,7%
#
# 5,2%
#
#  Otras
#
#  Nuclear
#
#  Fuel/Gas
#
#  CC Gas Natural
#
#  Renovables
#
#  Cogeneración de Alta Eﬁciencia
#
#  Carbón
#
# Impacto medioambiental
#
# El impacto ambiental de su electricidad depende de las fuentes energéticas utilizadas para su generación.
#
# En una escala de A a G donde A indica el mínimo impacto ambiental y G el máximo, y que el valor medio nacional corresponde al nivel D,
# la energía comercializada por Iberdrola tiene los siguientes valores.
#
# Emisiones de CO2
# Iberdrola Clientes
#
# Residuos Radiactivos Alta Actividad
# Iberdrola Clientes
#
# Emisiones de CO2 eq. (g/kWh) 161
# Media nacional (g/kWh) 162
#
# Residuos Radiactivos (µg/kWh) 441
# Media nacional (µg/kWh) 452
#
# Más información sobre el origen de su electricidad en gdo.cnmc.es
#
# De acuerdo con el sistema de Garantía de Origen e Información al Consumidor, implantado por la Comisión Nacional de la Energía, Iberdrola informa que toda la electricidad
# comercializada en 2022 ha sido etiquetada en la categoría D que indica un impacto ambiental igual a la media nacional.
#
# (cid:209)
#
# (cid:118)
# (cid:108)
# (cid:108)
# (cid:118)
#
# 0
# 1
# 0
# 0
# 0
# 0
# 0
# 1
#
# (cid:208)
#
# 6
# 8
# 5
# 1
#
# M
# O
# C
# G
# S
# N
# E
# G
# E
# 8
# 0
#
# 9
# 8
# 3
# 8
# 5
# 7
# 5
# 9
# -
# A
# F
# C
# -
# 1
# n
# ª
# ó
# c
# p
# i
# r
# c
# s
# n
#
# I
#
# i
#
# i
#
# ,
# 1
# 8
# 9
# 3
# 6
# -
# I
# B
# a
# o
# h
#
# j
#
# ,
#
# 9
# 1
# o
#
# i
# l
#
# o
# f
# ,
#
# 8
# 4
# 4
# 5
# o
# m
# o
# t
# ,
#
# i
#
# a
# a
# k
# z
# B
# e
# d
#
# i
#
# l
# i
# t
# n
# a
# c
# r
# e
# M
# o
# r
# t
# s
# g
# e
# R
#
# i
#
# l
# e
# n
# e
# a
# t
# i
# r
# c
# s
# n
#
# i
#
# ;
#
# o
# a
# b
#
# l
# i
#
# B
# 9
# 0
# 0
# 8
# 4
#
# ,
#
# 5
#
# i
#
# d
# a
# k
# s
# u
# E
# a
# a
# z
# l
# P
#
# i
#
# :
# l
# a
# c
# o
# s
# o
#
# i
#
# i
# l
# i
# c
# m
# o
# d
#
# ;
#
# d
# i
# r
# d
# a
# M
# 3
# 3
# 0
# 8
# 2
#
# ,
# 1
# o
# d
# n
# o
# d
# e
# R
# s
# á
# m
# o
# T
# /
# C
#
# :
# l
# a
# c
# s
# ﬁ
# o
#
# i
#
# i
# l
# i
# c
# m
# o
# d
# -
#
# .
#
# .
#
# U
# A
# S
#
# .
#
# ,
#
# I
#
# S
# E
# T
# N
# E
# L
# C
# A
# L
# O
# R
# D
# R
# E
# B
#
# I
# r
# o
# p
# o
# d
# i
# t
# i
#
# m
# e
# o
# t
# n
# e
# m
# u
# c
# o
# D

# %%
text_2= extract_text("..\\fact2.pdf")

# %%
print(text_2)
# Out:
# 9
# 8
# 3
# 8
# 5
# 7
# 5
# 9
# -
# A
# F
# C
# -
#
# I
#
# i
#
# ª
# 1
# n
# ó
# c
# p
# i
# r
# c
# s
# n
#
# i
#
# ,
# 1
# 8
# 9
# 3
# 6
# -
# I
# B
# a
# o
# h
#
# j
#
# ,
#
# 9
# 1
# o
#
# i
# l
#
# o
# f
#
# ,
#
# 8
# 4
# 4
# 5
# o
# m
# o
# t
#
# ,
#
# i
#
# a
# a
# k
# z
# B
# e
# d
#
# i
#
# l
# i
# t
# n
# a
# c
# r
# e
# M
# o
# r
# t
# s
# g
# e
# R
#
# i
#
# l
# e
# n
# e
# a
# t
# i
# r
# c
# s
# n
#
# i
#
# ;
#
# o
# a
# b
#
# l
# i
#
# B
# 9
# 0
# 0
# 8
# 4
#
# ,
#
# 5
#
# i
#
# d
# a
# k
# s
# u
# E
# a
# z
# a
# l
# P
#
# i
#
# :
# l
# a
# c
# o
# s
# o
#
# i
#
# i
# l
# i
# c
# m
# o
# d
#
# ;
#
# d
# i
# r
# d
# a
# M
# 3
# 3
# 0
# 8
# 2
#
# ,
# 1
# o
# d
# n
# o
# d
# e
# R
# s
# á
# m
# o
# T
# /
# C
#
# :
# l
# a
# c
# s
# i
# f
# o
#
# i
#
# i
# l
# i
# c
# m
# o
# d
# -
#
# .
#
# .
#
# U
# A
# S
#
# .
#
# ,
#
# I
#
# S
# E
# T
# N
# E
# L
# C
# A
# L
# O
# R
# D
# R
# E
# B
#
# I
#
# r
# o
# p
# o
# d
# i
# t
# i
#
# m
# e
# o
# t
# n
# e
# m
# u
# c
# o
# D
#
# FACTURA DE
# ELECTRICIDAD
#
# IBERDROLA CLIENTES, S.A.U.
# CIF A-95758389
#
# CONTRATO
#
# Titular
#
# Potencia:
#
# MIGUEL ANGEL CAMPOS HOYOS Potencia punta: 5,75 kW
# Potencia valle: 5,75 kW
#
# Remite: IBERDROLA CLIENTES, S.A.U. Apartado de Correos 61175 28080 Madrid
#
# DY 910 M S 0573663373 0 1 08
#
# SV03   004819   019207   20230920
#
# (cid:106)(cid:103)(cid:6)(cid:74)(cid:67)(cid:34)(cid:74)(cid:1)(cid:34)(cid:92)(cid:1)(cid:21)(cid:4)(cid:3)(cid:1)(cid:31)(cid:1)(cid:21)(cid:13)(cid:1)(cid:94)(cid:76)(cid:107)
# 05736633730033910020030200300020120093
#
# MIGUEL ANGEL CAMPOS HOYOS
#
# Pseo PEDRO SIMON ABRIL, 21, 1º 2
#
# Dirección de suministro:
#
# Plan A Tu Medida Contratado:
#
# 02003 ALBACETE
#
# Pseo PEDRO SIMON ABRIL, 21, 1º 2
# 02003 ALBACETE
#
# PLAN ELIGE 8 HORAS
#
# Nº DE CONTRATO: 573663373
#
# RESUMEN DE FACTURA
#
# PERIODO DE FACTURACIÓN:
# 08/08/2023 - 12/09/2023
#
# Nº FACTURA:
# 21230920010128369
#
# DIAS FACTURADOS:
# 35
#
# FECHA DE EMISIÓN:
# 20 de septiembre de 2023
#
# ENERGÍA.............................................................................72,96 €
#
# CARGOS NORMATIVOS .................................................. 1,35 €
#
# SERVICIOS Y OTROS CONCEPTOS.......................... 8,50 €
#
# IVA...........................................................................................5,35 €
#
# TOTAL
#
# 88,16 €
#
# FECHA PREVISTA DE COBRO: 28/09/2023
#
# Le informamos que la energía consumida es 100% renovable,
# certificada con Garantías de Origen emitidas por la CNMC.
#
# ¿LE PODEMOS AYUDAR?
#
# ps
#
# www.iberdrola.es    clientes@tuiberdrola.es
#
# APP Iberdrola Clientes
#
# Oficina de Atención Iberdrola:
# CALLE MARIA MARIN 54 02004 ALBACETE
# CALLE TEODORO CAMINO 12 12 02002 ALBACETE
#
# Atención al Cliente
# 900 225 235
# 925 05 99 06
#
# Reparaciones
# eléctricas del hogar
#
# 900 22 45 22
# 925 05 99 07
#
# Notificación
# de averías en la zona
#
# 900171171
#
# i-DE, Redes Eléctricas
# Inteligentes, S.A.U.
#
# 1/4
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         INFORMACIÓN SOBRE CONSUMO
#
#      EVOLUCIÓN DE CONSUMO (kWh)
#
# 1300
#
# 975
#
# 650
#
# 325
#
# kWh
#
# Jl.
# 22
#
# Ag.
# 22
#
# St.
# 22
#
# Oc.
# 22
#
# Nv.
# 22
#
# Nv.
# 22
#
# Dc.
# 22
#
# En.
# 23
#
# Fb.
# 23
#
# Mr.
# 23
#
# Ab.
# 23
#
# My.
# 23
#
# Jn.
# 23
#
# Jl.
# 23
#
# Ag.
# 23
#
# St.
# 23
#
#  HORAS PROMOCIONADAS
#
#  HORAS NO PROMOCIONADAS
#
# CONSUMOS
#
# 354 kWh
#
# 2,51 €
#
# 3,96 €
#
# Consumo total de
# esta factura.
#
# Consumo medio diario
# en esta factura.
#
# Consumo medio diario
# en los últimos 14 meses.
#
# Puede consultar el detalle de su consumo hora a hora en Mi Área Cliente en www.iberdrola.es
# y en la APP de Iberdrola Clientes. También puede acceder a los datos de medida de su
# contador inteligente a través de la web de su empresa distribuidora www.i-de.es/clientes.
#
# Periodo promocionado: 113,12 kWh
#
# Periodo no promocionado: 240,88 kWh
#
# Total: 354 kWh
#
# DETALLE DE FACTURA
# DETALLE DE FACTURA
#
# ENERGÍA
#
# Potencia facturada
#
# Total importe potencia hasta 12/09/2023
#
# Energía consumida
#
# Total 354 kWh hasta 12/09/2023
#
# CARGOS NORMATIVOS
#
# Financiación bono social fijo
#
# Impuesto sobre electricidad (*)
#
# TOTAL ENERGÍA
#
# SERVICIOS Y OTROS CONCEPTOS
#
# Alquiler equipos medida
#
# Protección Eléctrica Hogar
#
# TOTAL SERVICIOS Y OTROS CONCEPTOS
#
# IMPORTE TOTAL
#
# IVA Reducido (*)
#
# IVA
#
# TOTAL IMPORTE FACTURA
#
# Punta 5,75 kW x 35 días x 0,087756 €/kW día
#
# Valle 5,75 kW x 35 días x 0,004524 €/kW día
#
# Horas no promocionadas 240,88 kWh  x  0,190183 €/kWh
#
# Horas promocionadas 113,12 kWh  x  0,072551 €/kWh
#
# 18,57 €
#
# 54,02 €
#
# 35 días  x  0,038455 €/día
#
# 0,5% s/73,94 €
#
# 35 días  x  0,02663 €/día
#
# 1,14 meses  x  6,64 €/mes
#
# 5% s/75,24 €
#
# 21% s/7,57 €
#
# INFORMACION ADICIONAL
#
# NIF titular del contrato:
#
# Nº contador:
#
# Peaje de acceso a la red (ATR):
#
# 05162118K
#
# 0038291014
#
# 2.0TD
#
# Precios de peajes de acceso:
#
# B.O.E. del 22/12/2022
#
# El 13,3% está
# destinado a
# impuestos y cargos
#
# Fecha final del contrato:
#
# Empresa distribuidora:
#
# 10/09/2025
#
# i-DE, Redes Eléctricas Inteligentes, S.A.U.
#
# 19,4%
#
# Número de contrato de acceso:
#
# 0237380602
#
# Identificación punto de suministro (CUPS):
#
# ES 0021 0000 0024 6485 TZ
#
# Forma de pago:
#
# IBAN:
#
# BIC:
#
# Código de mandato:
#
# **** (Ocultos para su seguridad)
#
# DOMICILIACION BANCARIA
#
# ES92 0182 2857 1102 0158 ****
#
# BBVAESMMXXX
#
# 286921690000
#
# 64,7%
#
# 6,5%
#
# 1,1%
#
# 6,8%
#
# 1,5%
#
# Energía
# Peajes de Transporte y Distribución
#
# Impuestos
#
# Alquiler contador
#
# Bono Social
#
# Cargos
#
# Renovables, cogeneración y residuos
#
# Anualidades del déficit
#
# Sobrecoste generación no peninsular
#
# Otros
#
# 0,0%
#
# 5,5%
#
# 1,2%
#
# 0,1%
#
# (*) En virtud del Real Decreto-ley 17/2021, de 14 de septiembre, el impuesto especial sobre la electricidad aplicable a su factura se encuentra reducido
# del 5,11269632% al 0,5%.
#
# Las lecturas desagregadas según la tarifa de acceso, distintos a los periodos que tiene contratados, tomadas el 12/09/2023 son: punta: 24.146 kWh;
# llano: 19.913 kWh; valle 5.781 kWh, siendo estas lecturas reales. Sus consumos desagregados han sido punta: 68 kWh; llano: 98 kWh; valle 188 kWh.
#
# Las potencias máximas demandadas en el último año han sido 4,67 kW en P1 (punta) y 4,74 kW en P2 (valle).
#
# Para el periodo de esta factura el consumo medio de electricidad de los suministros en su mismo código postal ha sido de 199,72 kWh.
#
# El importe de los peajes de acceso a redes en esta factura, sin impuestos, es de 24,02 €, desglosado en: Potencia: 14,74 € , Energía: 8,35 €, Alquiler de
# contador: 0,93 €. Impuestos aplicables:  Impuesto Eléctrico e IVA u otros impuestos indirectos. Estos importes están englobados en el importe total de
# la factura (no representan coste adicional).
#
# Certificado PEFC. Este papel procede de bosques gestionados de forma sostenible y fuentes controladas. www.pefc.es
#
# 17,66 €
#
# 0,91 €
#
# 45,81 €
#
# 8,21 €
#
# 1,35 €
#
# 0,37 €
#
# 74,31 €
#
# 0,93 €
#
# 7,57 €
#
# 8,50 €
#
# 82,81 €
#
# 3,76 €
#
# 1,59 €
#
# 88,16 €
#
# 64,7%
# 19,4%
#
# 6,5%
#
# 1,1%
#
# 1,5%
#
# 6,8%
#
# (cid:209)
#
# (cid:176)
# (cid:108)
# (cid:118)
# (cid:109)
#
# 8
# 6
# 0
# 0
# 0
# 1
# 1
# 0
#
# (cid:208)
#
# 2/4
#
#
#
#
# Para reclamaciones relacionadas con el contrato de suministro o la facturación puede dirigirse a cualquiera de los canales de atención indicados en esta
# (cid:269)(cid:292)(cid:212)(cid:316)(cid:292)(cid:228)(cid:253)(cid:258)(cid:265)(cid:296)(cid:334)(cid:235)(cid:324)(cid:298)(cid:276)(cid:262)(cid:291)(cid:284)(cid:302)(cid:325)(cid:303)(cid:324)(cid:251)(cid:317)(cid:321)(cid:276)(cid:224)(cid:218)(cid:241)(cid:314)(cid:236)(cid:314)(cid:241)(cid:268)(cid:275)(cid:294)(cid:307)(cid:336)(cid:259)(cid:288)(cid:336)(cid:270)(cid:248)(cid:244)(cid:334)(cid:326)(cid:317)(cid:257)(cid:315)(cid:285)(cid:266)(cid:278)(cid:334)(cid:276)(cid:273)(cid:330)(cid:252)(cid:250)(cid:289)(cid:245)(cid:281)(cid:277)(cid:246)(cid:274)(cid:245)(cid:304)(cid:243)(cid:218)(cid:261)(cid:216)(cid:235)(cid:213)(cid:216)(cid:277)(cid:297)(cid:314)(cid:245)(cid:258)(cid:246)(cid:332)(cid:337)(cid:266)(cid:252)(cid:234)(cid:225)(cid:326)(cid:267)(cid:230)(cid:238)
# (cid:334)(cid:214)(cid:326)(cid:326)(cid:326)(cid:214)(cid:334)(cid:210)(cid:262)(cid:250)(cid:226)(cid:210)(cid:246)(cid:254)(cid:254)(cid:270)(cid:294)(cid:226)(cid:266)(cid:250)(cid:318)(cid:222)(cid:214)(cid:210)(cid:302)(cid:234)(cid:330)(cid:318)(cid:274)(cid:290)(cid:310)(cid:334)(cid:326)(cid:222)(cid:286)(cid:310)(cid:314)(cid:286)(cid:262)(cid:286)(cid:226)(cid:330)(cid:290)(cid:282)(cid:214)(cid:318)(cid:278)(cid:222)(cid:306)(cid:286)(cid:334)(cid:334)(cid:234)(cid:330)(cid:278)(cid:294)(cid:286)(cid:306)(cid:274)(cid:230)(cid:310)(cid:218)(cid:278)(cid:306)(cid:302)(cid:306)(cid:322)(cid:266)(cid:262)(cid:302)(cid:266)(cid:254)(cid:278)(cid:286)(cid:258)(cid:250)(cid:242)(cid:242)(cid:262)(cid:238)(cid:286)(cid:314)(cid:290)(cid:326)(cid:274)(cid:302)(cid:274)(cid:286)(cid:226)
#
# 3/4
#
#
# Página   4 / 4
#
# Origen de electricidad 2022
#
# Si bien la energía eléctrica que llega a nuestros hogares es indistinguible de la que consumen nuestros vecinos u otros consumidores
# conectados al mismo sistema eléctrico, es posible conocer el origen de la producción de energía eléctrica equivalente a la que
# consume en el hogar.
# A estos efectos, se proporciona el desglose de la mezcla de tecnologías de producción nacional para así comparar los porcentajes del
# promedio nacional con los correspondientes a la energía vendida por su Compañía Comercializadora.
#
# Iberdrola Clientes
#
# Origen
#
# Iberdrola Clientes Mix de generación nacional
#
# Renovable
#
# Cogen. Alta
# Eﬁciencia
#
# CC Gas Natural
#
# Carbón
#
# Fuel/Gas
#
# Nuclear
#
# Otras no renovables
#
# 42,7%
#
# 3,1%
#
# 25,1%
#
# 2,8%
#
# 1,1%
#
# 20,2%
#
# 5,0%
#
# 42,3%
#
# 2,1%
#
# 25,7%
#
# 2,9%
#
# 1,1%
#
# 20,7%
#
# 5,2%
#
#  Otras
#
#  Nuclear
#
#  Fuel/Gas
#
#  CC Gas Natural
#
#  Renovables
#
#  Cogeneración de Alta Eﬁciencia
#
#  Carbón
#
# Impacto medioambiental
#
# El impacto ambiental de su electricidad depende de las fuentes energéticas utilizadas para su generación.
#
# En una escala de A a G donde A indica el mínimo impacto ambiental y G el máximo, y que el valor medio nacional corresponde al nivel D,
# la energía comercializada por Iberdrola tiene los siguientes valores.
#
# Emisiones de CO2
# Iberdrola Clientes
#
# Residuos Radiactivos Alta Actividad
# Iberdrola Clientes
#
# Emisiones de CO2 eq. (g/kWh) 161
# Media nacional (g/kWh) 162
#
# Residuos Radiactivos (µg/kWh) 441
# Media nacional (µg/kWh) 452
#
# Más información sobre el origen de su electricidad en gdo.cnmc.es
#
# De acuerdo con el sistema de Garantía de Origen e Información al Consumidor, implantado por la Comisión Nacional de la Energía, Iberdrola informa que toda la electricidad
# comercializada en 2022 ha sido etiquetada en la categoría D que indica un impacto ambiental igual a la media nacional.
#
# (cid:209)
#
# (cid:176)
# (cid:108)
# (cid:108)
# (cid:110)
#
# 8
# 6
# 0
# 0
# 0
# 0
# 2
# 0
#
# (cid:208)
#
# 6
# 8
# 5
# 1
#
# M
# O
# C
# G
# S
# N
# E
# G
# E
# 8
# 0
#
# 9
# 8
# 3
# 8
# 5
# 7
# 5
# 9
# -
# A
# F
# C
# -
# 1
# n
# ª
# ó
# c
# p
# i
# r
# c
# s
# n
#
# I
#
# i
#
# i
#
# ,
# 1
# 8
# 9
# 3
# 6
# -
# I
# B
# a
# o
# h
#
# j
#
# ,
#
# 9
# 1
# o
#
# i
# l
#
# o
# f
# ,
#
# 8
# 4
# 4
# 5
# o
# m
# o
# t
# ,
#
# i
#
# a
# a
# k
# z
# B
# e
# d
#
# i
#
# l
# i
# t
# n
# a
# c
# r
# e
# M
# o
# r
# t
# s
# g
# e
# R
#
# i
#
# l
# e
# n
# e
# a
# t
# i
# r
# c
# s
# n
#
# i
#
# ;
#
# o
# a
# b
#
# l
# i
#
# B
# 9
# 0
# 0
# 8
# 4
#
# ,
#
# 5
#
# i
#
# d
# a
# k
# s
# u
# E
# a
# a
# z
# l
# P
#
# i
#
# :
# l
# a
# c
# o
# s
# o
#
# i
#
# i
# l
# i
# c
# m
# o
# d
#
# ;
#
# d
# i
# r
# d
# a
# M
# 3
# 3
# 0
# 8
# 2
#
# ,
# 1
# o
# d
# n
# o
# d
# e
# R
# s
# á
# m
# o
# T
# /
# C
#
# :
# l
# a
# c
# s
# ﬁ
# o
#
# i
#
# i
# l
# i
# c
# m
# o
# d
# -
#
# .
#
# .
#
# U
# A
# S
#
# .
#
# ,
#
# I
#
# S
# E
# T
# N
# E
# L
# C
# A
# L
# O
# R
# D
# R
# E
# B
#
# I
# r
# o
# p
# o
# d
# i
# t
# i
#
# m
# e
# o
# t
# n
# e
# m
# u
# c
# o
# D

# %%
# Define the regex pattern for CUPS code with optional spaces
cups_pattern = re.compile(r'\b[A-Za-z]{2}\s*\d{4}\s*\d{4}\s*\d{4}\s*\d{4}\s*[A-Za-z]{2}\b')

# Find all matches in the text
matches = cups_pattern.findall(text)

# Remove spaces from the extracted CUPS codes
cleaned_matches = [''.join(match.split()) for match in matches]

# Print the extracted and cleaned CUPS codes
for cleaned_match in cleaned_matches:
    print(cleaned_match)
# Out:
# ES0021000003518693SN

# %%
text
# Out:
# '9\n8\n3\n8\n5\n7\n5\n9\n-\nA\nF\nC\n-\n\nI\n\ni\n\nª\n1\nn\nó\nc\np\ni\nr\nc\ns\nn\n\ni\n\n,\n1\n8\n9\n3\n6\n-\nI\nB\na\no\nh\n\nj\n\n,\n\n9\n1\no\n\ni\nl\n\no\nf\n\n,\n\n8\n4\n4\n5\no\nm\no\nt\n\n,\n\ni\n\na\na\nk\nz\nB\ne\nd\n\ni\n\nl\ni\nt\nn\na\nc\nr\ne\nM\no\nr\nt\ns\ng\ne\nR\n\ni\n\nl\ne\nn\ne\na\nt\ni\nr\nc\ns\nn\n\ni\n\n;\n\no\na\nb\n\nl\ni\n\nB\n9\n0\n0\n8\n4\n\n,\n\n5\n\ni\n\nd\na\nk\ns\nu\nE\na\nz\na\nl\nP\n\ni\n\n:\nl\na\nc\no\ns\no\n\ni\n\ni\nl\ni\nc\nm\no\nd\n\n;\n\nd\ni\nr\nd\na\nM\n3\n3\n0\n8\n2\n\n,\n1\no\nd\nn\no\nd\ne\nR\ns\ná\nm\no\nT\n/\nC\n\n:\nl\na\nc\ns\ni\nf\no\n\ni\n\ni\nl\ni\nc\nm\no\nd\n-\n\n.\n\n.\n\nU\nA\nS\n\n.\n\n,\n\nI\n\nS\nE\nT\nN\nE\nL\nC\nA\nL\nO\nR\nD\nR\nE\nB\n\nI\n\nr\no\np\no\nd\ni\nt\ni\n\nm\ne\no\nt\nn\ne\nm\nu\nc\no\nD\n\nFACTURA DE\nELECTRICIDAD\n\nIBERDROLA CLIENTES, S.A.U.\nCIF A-95758389\n\nCONTRATO\n\nTitular\n\nADRIAN MORON BLANCO\n\nDirección de suministro:\n\nPlza ANDATZA, 4, 2º C  20160\nLASARTE-ORIA (GIPUZKOA)\n\nPotencia:\n\nPotencia punta: 3,3 kW\nPotencia valle: 3,3 kW\n\nNº DE CONTRATO: 867694233\n\nRESUMEN DE FACTURA\n\nPERIODO DE FACTURACIÓN:\n08/10/2023 - 08/11/2023\n\nNº FACTURA:\n21231113010286565\n\nDIAS FACTURADOS:\n31\n\nFECHA DE EMISIÓN:\n13 de noviembre de 2023\n\nENERGÍA............................................................................ 62,82 €\n\nDESCUENTOS ENERGÍA .............................................. -9,38 €\n\nCARGOS NORMATIVOS ................................................... 1,19 €\n\nSERVICIOS Y OTROS CONCEPTOS.......................... 0,83 €\n\nIVA........................................................................................... 2,77 €\n\nTOTAL\n\n58,23\xa0€\n\nFECHA PREVISTA DE COBRO: 21/11/2023\n\nRemite: IBERDROLA CLIENTES, S.A.U. Apartado de Correos 61175 28080 Madrid\n\nDY 910 M S 0867694233 0 1 08\n\nSV01   004959   019817   20231113\n\n(cid:106)(cid:103)(cid:9)(cid:68)(cid:70)(cid:43)(cid:34)(cid:1)(cid:34)(cid:92)(cid:3)(cid:2)(cid:61)(cid:21)(cid:91)(cid:21)(cid:1)(cid:11)(cid:12)(cid:32)(cid:14)(cid:6)(cid:107)\n08676942330033910201602090200010113113\n\nADRIAN MORON BLANCO\n\nPlza ANDATZA, 4, 2º C\n\n20160 LASARTE-ORIA (GIPUZKOA)\n\nPuede  encontrar  el  desglose  detallado  de  los  conceptos\nfacturados  en  el  reverso  de  esta  factura.  Además,  en\niberdrola.info/factura-luz le  explicamos con  detalle la  factura,\npara que entenderla sea más fácil que nunca.\n\n¿LE PODEMOS AYUDAR?\n\nps\n\nwww.iberdrola.es    clientes@tuiberdrola.es\n\nAPP Iberdrola Clientes\n\nOficina de Atención Iberdrola:\nCALLE MAYOR 44 20160 LASARTE-ORIA\nCALLE ELKANO KALEA 13 20120 HERNANI\n\nAtención al Cliente\n900 225 235\n94 646 01 25\n\nReparaciones\neléctricas del hogar\n\n900 22 45 22\n94 646 29 31\n\nNotificación\nde\xa0averías\xa0en\xa0la\xa0zona\n\n900171171\n\ni-DE, Redes Eléctricas\nInteligentes, S.A.U.\n\n1/4\n\n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n\x0c        INFORMACIÓN SOBRE CONSUMO\n\n     EVOLUCIÓN DE CONSUMO (kWh)\n\n400\n\n300\n\n200\n\n100\n\nkWh\n\nOc.\n23\n\nNv.\n23\n\nDETALLE DE FACTURA\nDETALLE DE FACTURA\n\nENERGÍA\n\nPotencia facturada\n\n242 kWh\n\n1,87 €\n\n2,17 €\n\nConsumo total de\nesta factura.\n\nConsumo medio diario\nen esta factura.\n\nConsumo medio diario\nen los últimos 1 meses.\n\nPuede consultar el detalle de su consumo hora a hora en Mi Área Cliente en www.iberdrola.es\ny en la APP de Iberdrola Clientes. También puede acceder a los datos de medida de su\ncontador inteligente a través de la web de su empresa distribuidora www.i-de.es/clientes.\n\nPunta 3,3 kW x 31 días x 0,099528 €/kW día\n\nValle 3,3 kW x 31 días x 0,016405 €/kW día\n\nTotal importe potencia hasta 08/11/2023\n\n11,86 €\n\nEnergía consumida\n\nDescuento sobre consumo 15%\n\nDescuento sobre T. Potencia\n\nCARGOS NORMATIVOS\n\nFinanciación bono social fijo\n\nImpuesto sobre electricidad (*)\n\nTOTAL ENERGÍA\n\nSERVICIOS Y OTROS CONCEPTOS\n\nAlq ...

# %%
link_patron = r'https?://\S+'

find_links = re.findall(link_patron, text)

for link in find_links:
    print(link)
# Out:
# https://comparador.cnmc.gob.es

# %%
info_cnmc = {
    "cups20": [],
    "start_date" : [],
    "end_date": [],
    "invoice_date": [],
    "consumption_total": [],
    "llane_consumption": [],
    "peak_consumption": [],
    "valley_consumption": []
}

# %%
import fitz  # PyMuPDF

def extract_link(pdf_path):
    doc = fitz.open(pdf_path)
    
    for pages_num in range(doc.page_count):
        page = doc[pages_num]
        enlaces = page.get_links()

        for enlace in enlaces:
            url = enlace.get('uri')
            if url:
                return url

    doc.close()

# %%
cups_pattern = re.compile(r'\b[A-Za-z]{2}\s*\d{4}\s*\d{4}\s*\d{4}\s*\d{4}\s*[A-Za-z]{2}\b')

# Find all matches in the text
matches = cups_pattern.findall(text)

# Remove spaces from the extracted CUPS codes
cleaned_matches = [''.join(match.split()) for match in matches]

# Print the extracted and cleaned CUPS codes
for cleaned_match in cleaned_matches:
    print(cleaned_match)

info_cnmc["cups20"] = cleaned_match
# Out:
# ES0021000003518693SN

# %%
ruta_pdf = 'pdf_moron.pdf'
link_cnmc = extract_link(ruta_pdf)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
import os

import time

# %%
driver = webdriver.Chrome()
driver.get(link_cnmc)
time.sleep(3)

# %%
info_cnmc["start_date"] = driver.find_element(By.XPATH, '/html/body/div[1]/div[1]/div[1]/div[2]/main/div[1]/section/div[1]/div[1]/div[1]/div[1]/span[2]').text
info_cnmc["end_date"] = driver.find_element(By.XPATH, '/html/body/div[1]/div[1]/div[1]/div[2]/main/div[1]/section/div[1]/div[1]/div[1]/div[2]/span[2]').text
info_cnmc["invoice_date"] = driver.find_element(By.XPATH, '/html/body/div[1]/div[1]/div[1]/div[2]/main/div[1]/section/div[1]/div[1]/div[1]/div[3]/span[2]').text
info_cnmc["consumption_total"] = driver.find_element(By.XPATH, '/html/body/div[1]/div[1]/div[1]/div[2]/main/div[1]/section/div[1]/div[1]/div[1]/div[7]/span[2]').text
info_cnmc["llane_consumption"] = driver.find_element(By.XPATH, '/html/body/div[1]/div[1]/div[1]/div[2]/main/div[1]/section/div[1]/div[1]/div[1]/div[9]/span[2]').text
info_cnmc["peak_consumption"] = driver.find_element(By.XPATH, '/html/body/div[1]/div[1]/div[1]/div[2]/main/div[1]/section/div[1]/div[1]/div[1]/div[8]/span[2]').text
info_cnmc["valley_consumption"] = driver.find_element(By.XPATH, '/html/body/div[1]/div[1]/div[1]/div[2]/main/div[1]/section/div[1]/div[1]/div[1]/div[10]/span[2]').text

# %%
info_cnmc
# Out:
# {'cups20': 'ES0021000003518693SN',
#  'start_date': '08/10/2023',
#  'end_date': '08/11/2023',
#  'invoice_date': '13/11/2023',
#  'consumption_total': '242 kWh',
#  'llane_consumption': '68 kWh',
#  'peak_consumption': '68 kWh',
#  'valley_consumption': '106 kWh'}

# %%
driver.close()

# %%
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    
    full_text = ""

    for page_num in range(doc.page_count):
        page = doc[page_num]
        page_text = page.get_text()
        full_text += page_text

    doc.close()

    return full_text

# %%
def save_text_to_txt(text, txt_path):
    with open(txt_path, 'w', encoding='utf-8') as txt_file:
        txt_file.write(text)

# %%
# Replace 'your_file.pdf' with the path to your PDF file
pdf_path = 'pdf_moron.pdf'
extracted_text = extract_text_from_pdf(pdf_path)
save_text_to_txt(extracted_text, "invoice.txt")

# Print the extracted text
print(extracted_text)
# Out:
# SV01   004959   019817   20231113
# FACTURA DE
# ELECTRICIDAD
# IBERDROLA CLIENTES, S.A.U.
# CIF A-95758389
# jg	DF+""\=[ k
# 08676942330033910201602090200010113113
# Remite: IBERDROLA CLIENTES, S.A.U. Apartado de Correos 61175 28080 Madrid
# DY 910 M S 0867694233 0 1 08
# ADRIAN MORON BLANCO
# Plza ANDATZA, 4, 2º C
# 20160 LASARTE-ORIA (GIPUZKOA)
# CONTRATO
# Titular
# Potencia:
# ADRIAN MORON BLANCO
# Potencia punta: 3,3 kW
# Potencia valle: 3,3 kW
# Dirección de suministro:
# Plza ANDATZA, 4, 2º C  20160
# LASARTE-ORIA (GIPUZKOA)
# Nº DE CONTRATO: 867694233
# RESUMEN DE FACTURA
# PERIODO DE FACTURACIÓN:
# 08/10/2023 - 08/11/2023
# Nº FACTURA:
# 21231113010286565
# DIAS FACTURADOS:
# 31
# FECHA DE EMISIÓN:
# 13 de noviembre de 2023
#
# ENERGÍA............................................................................ 62,82 €
# DESCUENTOS ENERGÍA ..............................................-9,38 €
# CARGOS NORMATIVOS ................................................... 1,19 €
# SERVICIOS Y OTROS CONCEPTOS.......................... 0,83 €
# IVA........................................................................................... 2,77 €
# TOTAL
# 58,23 €
# FECHA PREVISTA DE COBRO: 21/11/2023
# www.iberdrola.es
#    clientes@tuiberdrola.es
# APP Iberdrola Clientes
# Oficina de Atención Iberdrola:
# Atención al Cliente
# 900 225 235
# 94 646 01 25
# Notificación
# de averías en la zona
# 900171171
# Reparaciones
# eléctricas del hogar
# 900 22 45 22
# 94 646 29 31
# i-DE, Redes Eléctricas
# Inteligentes, S.A.U.
# ¿LE PODEMOS AYUDAR?
# ps
# CALLE MAYOR 44 20160 LASARTE-ORIA
# CALLE ELKANO KALEA 13 20120 HERNANI
# Puede encontrar el desglose detallado de los conceptos
# facturados en el reverso de esta factura. Además, en
# iberdrola.info/factura-luz le explicamos con detalle la factura,
# para que entenderla sea más fácil que nunca.
# 1/4
# Documento emitido por IBERDROLA CLIENTES, S.A.U. - domicilio fiscal: C/ Tomás Redondo 1, 28033 Madrid; domicilio social: Plaza Euskadi 5, 48009 Bilbao; inscrita en el Registro Mercantil de Bizkaia, tomo 5448, folio 19, hoja BI-63981, inscripción 1ª - CIF A-95758389
# ÐuvlvÑ
# 09100010
#         INFORMACIÓN SOBRE CONSUMO
# Oc.
# 23
# Nv.
# 23
# kWh
# 100
# 200
# 300
# 400
# Consumo total de
# esta factura.
# Consumo medio diario
# en esta factura.
# Consumo medio diario
# en los últimos 1 meses.
# 242 kWh
# 1,87 €
# 2,17 €
# Puede consultar el detalle de su consumo hora a hora en Mi Área Cliente en www.iberdrola.es
# y en la APP de Iberdrola Clientes. También puede acceder a los datos de medida de su
# contador inteligente a través de la web de su empresa distribuidora www.i-de.es/clientes.
#
#      EVOLUCIÓN DE CONSUMO (kWh)
#
#
# DETALLE DE FACTURA
# DETALLE DE FACTURA
# INFORMACION ADICIONAL
# El 13,3% está
# destinado a
# impuestos y cargos
# 66,1%
# 17,2%
# 5,2%
# 1,4%
# 8,1%
# 2,0%
# Energía
# 66,1%
# Peajes de Transporte y Distribución
# 17,2%
# Impuestos
# 5,2%
# Alquiler contador
# 1,4%
# Bono Social
# 2,0%
# Cargos
# 8,1%
# Renovables, cogeneración y residuos
# 0,0%
# Anualidades del déficit
# 6,5%
# Sobrecoste generación no peninsular
# 1,5%
# Otros
# 0,1%
# ENERGÍA
# Potencia facturada
# Punta 3,3 kW x 31 días x 0,099528 €/kW día
# 10,18 €
# Valle 3,3 kW x 31 días x 0,016405 €/kW día
# 1,68 €
# Total importe potencia hasta 08/11/2023
# 11,86 €
# Energía consumida
# 242 kWh  x  0,209469 €/kWh
# 50,69 €
# Descuento sobre consumo 15%
# 15% s/50,69 €
# -7,60 €
# Descuento sobre T. Potencia
# 15% s/11,86 €
# -1,78 €
# CARGOS NORMATIVOS
# Financiación bono social fijo
# 31 días  x  0,038455 €/día
# 1,19 €
# Impuesto sobre electricidad (*)
# 0,5% s/54,36 €
# 0,27 €
# TOTAL ENERGÍA
# 54,63 €
# SERVICIOS Y OTROS CONCEPTOS
# Alquiler equipos medida
# 31 días  x  0,02663 €/día
# 0,83 €
# Asistente Smart Iberdrola
# 1,01 meses  x  0,99 €/mes
# 1,00 €
# Dto Asistente Smart
# 100% s/1 €
# -1,00 €
# TOTAL SERVICIOS Y OTROS CONCEPTOS
# 0,83 €
# IMPORTE TOTAL
# 55,46 €
# IVA Reducido (*)
# 5% s/55,46 €
# 2,77 €
# TOTAL IMPORTE FACTURA
# 58,23 €
# NIF titular del contrato:
# 53901164C
# Nº contador:
# 0000082040
# Peaje de acceso a la red (ATR):
# 2.0TD
# Precios de peajes de acceso:
# B.O.E. del 22/12/2022
# Fecha final del contrato:
# 06/10/2024
# Empresa distribuidora:
# i-DE, Redes Eléctricas Inteligentes, S.A.U.
# Número de contrato de acceso:
# 0027783790
# Identificación punto de suministro (CUPS):
# ES 0021 0000 0351 8693 SN
# Forma de pago:
# DOMICILIACION BANCARIA
# IBAN:
# ES65 0030 1137 6003 9086 ****
# BIC:
# BSCHESMMXXX
# Código de mandato:
# 275464214000
# **** (Ocultos para su seguridad)
# (*) En virtud del Real Decreto-ley 17/2021, de 14 de septiembre, el impuesto especial sobre la electricidad aplicable a su factura se encuentra reducido
# del 5,11269632% al 0,5%.
# Las lecturas desagregadas según la tarifa de acceso, tomadas el 08/11/2023 son: punta: 1.319 kWh; llano: 1.021 kWh; valle 324 kWh, siendo estas lecturas
# reales. Sus consumos desagregados han sido punta: 68 kWh; llano: 68 kWh; valle 106 kWh.
# Las potencias máximas demandadas en el último año han sido 2,64 kW en P1 (punta) y 2,7 kW en P2 (valle).
# Para el periodo de esta factura el consumo medio de electricidad de los suministros en su mismo código postal ha sido de 159,21 kWh.
# El importe de los peajes de acceso a redes en esta factura, sin impuestos, es de 15,56 €, desglosado en: Potencia: 7,49 € , Energía: 7,24 €, Alquiler de
# contador: 0,83 €. Impuestos aplicables:  Impuesto Eléctrico e IVA u otros impuestos indirectos. Estos importes están englobados en el importe total de
# la factura (no representan coste adicional).
# Para reclamaciones relacionadas con el contrato de suministro o la facturación puede dirigirse a cualquiera de los canales de atención indicados en esta
# factura, o en el Apartado de Correos 61090, 28080 de Madrid. Si su reclamación no ha sido resuelta o ha superado el plazo de 30 días, puede dirigirse a
# la Junta Arbitral de Consumo de su Comunidad Autónoma. Además puede acudir a los órganos competentes en materia de Consumo y/o Energía de
# dicha Comunidad Autónoma.
# 2/4
# čĤÔüĤĤýĒőĥĜİÞÖøĸěĪëĮāīĞĽÝĆőĸıĊŌÚāÞüáłĚĂĲŎďøôŎĐĵćķêëđĮĔġŊĬÚġĩäĕĖĝñĬĲĞĮĐôĹńĵĨĺÓċĄĮđúĬĚáîïŎÖ
# ŎÖņņņÖŎÒĆÚæĺľľĺĢæúĖêĞÖêþĲĞņöĦĒłĒłĂúŎòĺòþÚÖêĖÞĊņêĢĊņĮúŊĖĦŎŊĞÞĮĚŊľþĲŊúâĢîÞĶîÚþĚÒÚĮĖľĒņĒîÒĞâ
# (*) En virtud del Real Decreto-ley 12/2021, de 24 de junio, el IVA aplicable a su factura se encuentra reducido del 21% al 5%.
# En el código QR o en el enlace https://comparador.cnmc.gob.es puede consultar y comparar las distintas ofertas vigentes de
# las comercializadoras de energía eléctrica en mercado libre.
# ÐvllvÑ
# 10000010
# Documento emitido por IBERDROLA CLIENTES, S.A.U. - domicilio ﬁscal: C/ Tomás Redondo 1, 28033 Madrid; domicilio social: Plaza Euskadi 5, 48009 Bilbao; inscrita en el Registro Mercantil de Bizkaia, tomo 5448, folio 19, hoja BI-63981, inscripción 1ª - CIF A-95758389
# Si bien la energía eléctrica que llega a nuestros hogares es indistinguible de la que consumen nuestros vecinos u otros consumidores
# conectados al mismo sistema eléctrico, es posible conocer el origen de la producción de energía eléctrica equivalente a la que
# consume en el hogar.
# A estos efectos, se proporciona el desglose de la mezcla de tecnologías de producción nacional para así comparar los porcentajes del
# promedio nacional con los correspondientes a la energía vendida por su Compañía Comercializadora.
# Origen de electricidad 2022
# El impacto ambiental de su electricidad depende de las fuentes energéticas utilizadas para su generación.
# En una escala de A a G donde A indica el mínimo impacto ambiental y G el máximo, y que el valor medio nacional corresponde al nivel D,
# la energía comercializada por Iberdrola tiene los siguientes valores.
# Impacto medioambiental
#  Otras    Nuclear    Fuel/Gas    CC Gas Natural    Renovables    Cogeneración de Alta Eﬁciencia    Carbón
# Origen
# Iberdrola Clientes
# Mix de generación nacional
# Renovable
# 42,7%
# 42,3%
# Cogen. Alta
# Eﬁciencia
# 3,1%
# 2,1%
# CC Gas Natural
# 25,1%
# 25,7%
# Carbón
# 2,8%
# 2,9%
# Fuel/Gas
# 1,1%
# 1,1%
# Nuclear
# 20,2%
# 20,7%
# Otras no renovables
# 5,0%
# 5,2%
# Iberdrola Clientes
# Emisiones de CO2 eq. (g/kWh) 161
# Media nacional (g/kWh) 162
# Emisiones de CO2
# Iberdrola Clientes
# Residuos Radiactivos (µg/kWh) 441
# Media nacional (µg/kWh) 452
# Residuos Radiactivos Alta Actividad
# Iberdrola Clientes
# Más información sobre el origen de su electricidad en gdo.cnmc.es
# De acuerdo con el sistema de Garantía de Origen e Información al Consumidor, implantado por la Comisión Nacional de la Energía, Iberdrola informa que toda la electricidad
# comercializada en 2022 ha sido etiquetada en la categoría D que indica un impacto ambiental igual a la media nacional.
# 08 EGEN SGCOM 1586
# Página   4 / 4
