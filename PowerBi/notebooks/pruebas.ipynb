# %%
import pandas as pd

# %%
df = pd.read_csv('reporte_analitico/Data/Dataset_energia.csv')
df
# Out:
#                Asesor      Cliente  Codigo Postal  \
# 0   Aurora Montenegro    Cliente 1           8015
# 1   Aurora Montenegro    Cliente 2          41001
# 2   Aurora Montenegro    Cliente 3          15001
# 3   Aurora Montenegro    Cliente 4          46001
# 4   Aurora Montenegro    Cliente 5           7001
# ..                ...          ...            ...
# 95     Martín Alarcón   Cliente 96           8009
# 96     Martín Alarcón   Cliente 97           1008
# 97     Martín Alarcón   Cliente 98          28009
# 98     Martín Alarcón   Cliente 99          41009
# 99     Martín Alarcón  Cliente 100          28001
#
#                       Ubicación                    Cups            Compañía  \
# 0   Alcalá del Júcar (Albacete)  ES34567890123456789012           Iberdrola
# 1                Frías (Burgos)  ES45678901234567890123              Endesa
# 2                Ronda (Málaga)  ES56789012345678901234             Naturgy
# ...
